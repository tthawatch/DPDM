# %% [markdown]
# <a href="https://colab.research.google.com/github/tthawatch/DPDM/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
base_path = '/content/drive/My Drive/DWDM_material'

# %%
os.listdir('/content/drive/My Drive/DWDM_material')
# Out:
# ['test.csv',
#  'Preprocessing02.html',
#  'reduced_marketbasket.csv',
#  'search_click.csv',
#  'teach.csv',
#  'teach02.csv',
#  'w_restaurant.csv',
#  '03 สังคม.xls',
#  '52835793_259306464964511_3851804852342489088_n (1).png',
#  'Copy of search_click (1).csv',
#  'Copy of w_restaurant (1).csv',
#  'metadata (1).xlsx',
#  'a6b698d8efa85a3159c034c250c7a68e.jpg',
#  '2-58 (1).pdf',
#  'animal.csv',
#  'Project3.xlsx',
#  'Project2.xlsx',
#  '2015-ogd1-2 (1).csv',
#  'untitled-12 (2).xlsx',
#  'Project1.xlsx',
#  'project.xlsx']

# %%
file_path_1 = os.path.join(base_path,'Project1.xlsx')

# %%
Data_1=pd.read_excel(file_path_1)

# %%
Data_1
# Out:
#     รหัสจังหวัด            จังหวัด  ...   สัตว์ปีกอื่นๆ(ตัว)   รวมสัตว์เลี้ยงทั้งหมด
# 0            10     กรุงเทพมหานคร   ...                  4669                 593428
# 1            12           นนทบุรี   ...                  1072                 469505
# 2            13          ปทุมธานี   ...                     6                 879020
# 3            14   พระนครศรีอยุธยา   ...                  2337                6080808
# 4            15           อ่างทอง   ...                  2043                5617443
# ..          ...                ...  ...                   ...                    ...
# 72           90             สงขลา   ...                  7838                6129618
# 73           91              สตูล   ...                   429                1447423
# 74           94           ปัตตานี   ...                  1489                1421811
# 75           95              ยะลา   ...                 11216                 968039
# 76           96          นราธิวาส   ...                   846                 748497
#
# [77 rows x 65 columns]

# %%
file_path_2 = os.path.join(base_path,'project.xlsx')

# %%
Data_2=pd.read_excel(file_path_2)

# %%
Data_2
# Out:
#             จังหวัด  ...  ผลผลิตต่อเนื้อที่เก็บเกี่ยว(กก.)
# 0         เพชรบูรณ์  ...                            781.92
# 1        นครราชสีมา  ...                            776.32
# 2              น่าน  ...                            692.91
# 3               ตาก  ...                            736.82
# 4               เลย  ...                            712.99
# 5          เชียงราย  ...                            756.64
# 6         นครสวรรค์  ...                            775.49
# 7          พิษณุโลก  ...                            766.16
# 8              แพร่  ...                            724.21
# 9             พะเยา  ...                            764.67
# 10           ลพบุรี  ...                            735.45
# 11          สระบุรี  ...                            808.22
# 12            ลำปาง  ...                            739.52
# 13        อุตรดิตถ์  ...                            713.09
# 14        เชียงใหม่  ...                            755.37
# 15        อุทัยธานี  ...                            878.55
# 16          สระแก้ว  ...                            803.73
# 17          ชัยภูมิ  ...                            729.59
# 18        กำแพงเพชร  ...                            748.47
# 19        กาญจนบุรี  ...                            740.66
# 20            ลำพูน  ...                            749.41
# 21      อุบลราชธานี  ...                            748.16
# 22          สุโขทัย  ...                            707.74
# 23       แม่ฮ่องสอน  ...                            726.00
# 24       สุพรรณบุรี  ...                            775.34
# 25           พิจิตร  ...                            726.37
# 26         ศรีสะเกษ  ...                            782.66
# 27      หนองบัวลำภู  ...                            707.89
# 28       ปราจีนบุรี  ...                            783.51
# 29         จันทบุรี  ...                            731.79
# 30           ชัยนาท  ...                            738.52
# 31          ขอนแก่น  ...                            664.73
# 32         ร้อยเอ็ด  ...                            667.45
# 33        กาฬสินธุ์  ...                            598.32
# 34         เพชรบุรี  ...                            657.57
# 35         อุดรธานี  ...                            723.51
# 36       ฉะเชิงเทรา  ...                            729.07
# 37       อำนาจเจริญ  ...                            702.29
# 38           สกลนคร  ...                            672.97
# 39        บุรีรัมย์  ...                            677.56
# 40         สุรินทร์  ...                            683.32
# 41          ราชบุรี  ...                            631.76
# 42          หนองคาย  ...                            452.32
# 43         มุกดาหาร  ...                            701.04
# 44           นครพนม  ...                            687.19
# 45  ประจวบคีรีขันธ์  ...                            640.46
# 46            ยโสธร  ...                            692.41
# 47        มหาสารคาม  ...                            681.37
#
# [48 rows x 5 columns]

# %%
Data_table_2 = Data_2.iloc[:,1:5] 
Data_table_2
# Out:
#     รหัสจังหวัด  ...  ผลผลิตต่อเนื้อที่เก็บเกี่ยว(กก.)
# 0            67  ...                            781.92
# 1            30  ...                            776.32
# 2            55  ...                            692.91
# 3            63  ...                            736.82
# 4            42  ...                            712.99
# 5            57  ...                            756.64
# 6            60  ...                            775.49
# 7            65  ...                            766.16
# 8            54  ...                            724.21
# 9            56  ...                            764.67
# 10           16  ...                            735.45
# 11           19  ...                            808.22
# 12           52  ...                            739.52
# 13           53  ...                            713.09
# 14           50  ...                            755.37
# 15           61  ...                            878.55
# 16           27  ...                            803.73
# 17           36  ...                            729.59
# 18           62  ...                            748.47
# 19           71  ...                            740.66
# 20           51  ...                            749.41
# 21           34  ...                            748.16
# 22           64  ...                            707.74
# 23           58  ...                            726.00
# 24           72  ...                            775.34
# 25           66  ...                            726.37
# 26           33  ...                            782.66
# 27           39  ...                            707.89
# 28           25  ...                            783.51
# 29           22  ...                            731.79
# 30           18  ...                            738.52
# 31           40  ...                            664.73
# 32           45  ...                            667.45
# 33           46  ...                            598.32
# 34           76  ...                            657.57
# 35           41  ...                            723.51
# 36           24  ...                            729.07
# 37           37  ...                            702.29
# 38           47  ...                            672.97
# 39           31  ...                            677.56
# 40           32  ...                            683.32
# 41           70  ...                            631.76
# 42           43  ...                            452.32
# 43           49  ...                            701.04
# 44           48  ...                            687.19
# 45           77  ...                            640.46
# 46           35  ...                            692.41
# 47           44  ...                            681.37
#
# [48 rows x 4 columns]

# %%
file_path_3 = os.path.join(base_path,'Project3.xlsx')

# %%
Data_3=pd.read_excel(file_path_3 )

# %%
Data_3
# Out:
#       province             ภูมิภาค
# 0   อำนาจเจริญ  ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ  ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์  ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ  ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์  ตะวันออกเฉียงเหนือ
# ..         ...                 ...
# 72       พังงา                 ใต้
# 73      ภูเก็ต                 ใต้
# 74       ระนอง                 ใต้
# 75        สตูล                 ใต้
# 76        ตรัง                 ใต้
#
# [77 rows x 2 columns]

# %%
Data_1.shape
# Out:
# (77, 65)

# %%
Data_2.shape
# Out:
# (48, 5)

# %%
Data_3.shape
# Out:
# (77, 2)

# %%
merged_table = Data_1.merge(Data_table_2,how='left',left_on='รหัสจังหวัด',right_on='รหัสจังหวัด') #how=กำหนดตารางหลัก left_on ข้อมูลที่ตรงกันสอดคล้องกันนำมารวมกัน
merged_table
# Out:
#     รหัสจังหวัด  ... ผลผลิตต่อเนื้อที่เก็บเกี่ยว(กก.)
# 0            10  ...                              NaN
# 1            12  ...                              NaN
# 2            13  ...                              NaN
# 3            14  ...                              NaN
# 4            15  ...                              NaN
# ..          ...  ...                              ...
# 72           90  ...                              NaN
# 73           91  ...                              NaN
# 74           94  ...                              NaN
# 75           95  ...                              NaN
# 76           96  ...                              NaN
#
# [77 rows x 68 columns]

# %%
merged_table.isnull()
# Out:
#     รหัสจังหวัด  ...  ผลผลิตต่อเนื้อที่เก็บเกี่ยว(กก.)
# 0         False  ...                              True
# 1         False  ...                              True
# 2         False  ...                              True
# 3         False  ...                              True
# 4         False  ...                              True
# ..          ...  ...                               ...
# 72        False  ...                              True
# 73        False  ...                              True
# 74        False  ...                              True
# 75        False  ...                              True
# 76        False  ...                              True
#
# [77 rows x 68 columns]

# %%
merged_table.isnull().any()
# Out:
# รหัสจังหวัด                                  False
# จังหวัด                                      False
# โคพื้นเมืองเพศผู้(ตัว)                       False
# โคพื้นเมืองเพศเมีย แรกเกิดถึงโคสาว(ตัว)      False
# โคพื้นเมืองเพศเมีย ตั้งท้องแรกขึ้นไป(ตัว)    False
#                                              ...
#  สัตว์ปีกอื่นๆ(ตัว)                          False
# รวมสัตว์เลี้ยงทั้งหมด                        False
# ผลผลิต(ตัน)                                   True
# เนื้อที่เก็บเกี่ยว(ไร่)                       True
# ผลผลิตต่อเนื้อที่เก็บเกี่ยว(กก.)              True
# Length: 68, dtype: bool

# %%
merged_table.isnull().any().any()
# Out:
# True

# %%
merged_table_nm = merged_table.dropna()

# %%
merged_table_nm
# Out:
#     รหัสจังหวัด  ... ผลผลิตต่อเนื้อที่เก็บเกี่ยว(กก.)
# 5            16  ...                           735.45
# 7            18  ...                           738.52
# 8            19  ...                           808.22
# 12           22  ...                           731.79
# 14           24  ...                           729.07
# 15           25  ...                           783.51
# 17           27  ...                           803.73
# 18           30  ...                           776.32
# 19           31  ...                           677.56
# 20           32  ...                           683.32
# 21           33  ...                           782.66
# 22           34  ...                           748.16
# 23           35  ...                           692.41
# 24           36  ...                           729.59
# 25           37  ...                           702.29
# 27           39  ...                           707.89
# 28           40  ...                           664.73
# 29           41  ...                           723.51
# 30           42  ...                           712.99
# 31           43  ...                           452.32
# 32           44  ...                           681.37
# 33           45  ...                           667.45
# 34           46  ...                           598.32
# 35           47  ...                           672.97
# 36           48  ...                           687.19
# 37           49  ...                           701.04
# 38           50  ...                           755.37
# 39           51  ...                           749.41
# 40           52  ...                           739.52
# 41           54  ...                           724.21
# 42           55  ...                           692.91
# 43           56  ...                           764.67
# 44           57  ...                           756.64
# 45           58  ...                           726.00
# 46           53  ...                           713.09
# 47           60  ...                           775.49
# 48           61  ...                           878.55
# 49           62  ...                           748.47
# 50           63  ...                           736.82
# 51           64  ...                           707.74
# 52           65  ...                           766.16
# 53           66  ...                           726.37
# 54           67  ...                           781.92
# 55           70  ...                           631.76
# 56           71  ...                           740.66
# 57           72  ...                           775.34
# 61           76  ...                           657.57
# 62           77  ...                           640.46
#
# [48 rows x 68 columns]

# %%
merged_table_nm.shape
# Out:
# (48, 68)

# %%
merged_table_nm.isnull().any().any()
# Out:
# False

# %%
print(merged_table.shape)
print(merged_table_nm.shape)
# Out:
# (77, 68)
# (48, 68)

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(merged_table_nm['ผลผลิต(ตัน)'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f349f7add68>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f349f7c3780>,
#   <matplotlib.lines.Line2D at 0x7f349f7c3b00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f349f8beda0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f349f7c3e80>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f349f7c30b8>,
#   <matplotlib.lines.Line2D at 0x7f349f7c3400>]}

# %%
plt.boxplot(merged_table_nm['ผลผลิต(ตัน)'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f349f263ba8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f349f2705f8>,
#   <matplotlib.lines.Line2D at 0x7f349f270978>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f349f2790b8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f349f270cf8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f349f263eb8>,
#   <matplotlib.lines.Line2D at 0x7f349f270278>]}

# %%
ret = plt.boxplot(merged_table_nm['ผลผลิต(ตัน)'],vert=False)
